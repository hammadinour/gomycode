# %% [markdown]
# <a href="https://colab.research.google.com/github/hammadinour/gomycode/blob/main/xo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tkinter as tk
import tkinter.messagebox as messagebox
#importing pillow library after installing the library : pip (package installer for Pythonr) install pillow
from PIL import ImageTk,Image



window = tk.Tk()
window.title("TIC-TAC-TOE")


#insert icon for the window afeter converting an image into .ico form
window.iconbitmap('C:/Users/azizh/Downloads/python nour/logo.ico')



clicked = True
count = 0


#insert image into the programme after installing pillow and importing the module
info_im=ImageTk.PhotoImage (Image.open("game-info.ico"))



def disable_all_buttons() :
    b1.config(state=DISABLED)
    b2.config(state=DISABLED)
    b3.config(state=DISABLED)
    b4.config(state=DISABLED)
    b5.config(state=DISABLED)
    b6.config(state=DISABLED)
    b7.config(state=DISABLED)
    b8.config(state=DISABLED)
    b9.config(state=DISABLED)



def checkifwon() :
    global winner
    winner =False
    if b1["text"]== "x" and b2["text"]== "x" and b3["text"]== "x" :
        b1.config (bg="#ACC740")
        b2.config (bg="#ACC740")
        b3.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
    elif b4["text"]== "x" and b5["text"]== "x" and b6["text"]== "x" :
        b4.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b6.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
    elif b7["text"]== "x" and b8["text"]== "x" and b9["text"]== "x" :
        b7.config (bg="#ACC740")
        b8.config (bg="#ACC740")
        b9.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
    elif b1["text"]== "x" and b4["text"]== "x" and b7["text"]== "x" :
        b1.config (bg="#ACC740")
        b4.config (bg="#ACC740")
        b7.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
    elif b2["text"]== "x" and b5["text"]== "x" and b8["text"]== "x" :
        b2.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b8.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
    elif b3["text"]== "x" and b6["text"]== "x" and b9["text"]== "x" :
        b3.config (bg="#ACC740")
        b6.config (bg="#ACC740")
        b9.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
    elif b1["text"]== "x" and b5["text"]== "x" and b9["text"]== "x" :
        b1.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b9.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
    elif b3["text"]== "x" and b5["text"]== "x" and b7["text"]== "x" :
        b3.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b7.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","x wins")
        disable_all_buttons()
#ooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
    elif b1["text"]== "o" and b2["text"]== "o" and b3["text"]== "o" :
        b1.config (bg="#ACC740")
        b2.config (bg="#ACC740")
        b3.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("o wins")
        disable_all_buttons()
    elif b4["text"]== "o" and b5["text"]== "o" and b6["text"]== "o" :
        b4.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b6.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","o wins")
        disable_all_buttons()
    elif b7["text"]== "o" and b8["text"]== "o" and b9["text"]== "o" :
        b7.config (bg="#ACC740")
        b8.config (bg="#ACC740")
        b9.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","o wins")
        disable_all_buttons()
    elif b1["text"]== "o" and b4["text"]== "o" and b7["text"]== "o" :
        b1.config (bg="#ACC740")
        b4.config (bg="#ACC740")
        b7.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","o wins")
        disable_all_buttons()
    elif b2["text"]== "o" and b5["text"]== "o" and b8["text"]== "o" :
        b2.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b8.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","o wins")
        disable_all_buttons()
    elif b3["text"]== "o" and b6["text"]== "o" and b9["text"]== "o" :
        b3.config (bg="#ACC740")
        b6.config (bg="#ACC740")
        b9.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","o wins")
        disable_all_buttons()
    elif b1["text"]== "o" and b5["text"]== "o" and b9["text"]== "o" :
        b1.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b9.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","o wins")
        disable_all_buttons()
    elif b3["text"]== "o" and b5["text"]== "o" and b7["text"]== "o" :
        b3.config (bg="#ACC740")
        b5.config (bg="#ACC740")
        b7.config (bg="#ACC740")
        winner=True
        messagebox.showinfo ("TIC-TAC-TOE","o wins")
        disable_all_buttons()
    if count == 9 and winner==False :
        messagebox.showinfo("TIC-TAC-TOE","it's a tie")
        disable_all_buttons()

def b_click(b) :
    global clicked , count

    if b["text"]== " " and clicked == True :
        b["text"] ="x"
        clicked = False
        count += 1
        checkifwon()
    elif b["text"]==" " and clicked == False:
            b["text"] ="o"
            clicked = True
            count += 1
            checkifwon()
    else :
        messagebox.showerror("TIC-TAC-TOE","box already selected")





def reset():
    global b1,b2,b3,b4,b5,b5,b6,b7,b8,b9
    global clicked ,count
    clicked =True
    count = 0
    b1 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8 , bg ="white" , command = lambda : b_click(b1))
    b2 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b2))
    b3 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b3))
    b4 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b4))
    b5 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b5))
    b6 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b6))
    b7 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b7))
    b8 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b8))
    b9 = tk.Button (window,text=' ',font=("arial",40),height =4 , width=8, bg ="white" , command = lambda : b_click(b9))




    b1.grid(row=0,column=0)
    b2.grid(row=0,column=1)
    b3.grid(row=0,column=2)
    b4.grid(row=1,column=0)
    b5.grid(row=1,column=1)
    b6.grid(row=1,column=2)
    b7.grid(row=2,column=0)
    b8.grid(row=2,column=1)
    b9.grid(row=2,column=2)



def open_secondary_window():
    # Create secondary (or popup) window.
    secondary_window = tk.Toplevel()
    secondary_window.title("how to play ?")
    secondary_window.config(width=300, height=200)

    info_label=tk.Label(secondary_window,image=info_im)
    info_label.pack()

    rules=tk.Label(secondary_window,text="Players take turns putting their marks in empty squares.The first player to get 3 marks in a row (up, down, across, or diagonally) is the winner.When all 9 squares are full, the game is over.")
    rules.pack()
    extra_info =tk.Label(secondary_window,text="this game involves two players, one designated as X and the other as O.the player 'x'gets to start first")
    extra_info.pack()

    # Create a button to close (destroy) this window.
    button_close = tk.Button(secondary_window,text="back to game",command=secondary_window.destroy)
    button_close.pack()

#creating a menu for various options
my_menu = tk.Menu(window)
window.config(menu=my_menu)


options_menu = tk.Menu(my_menu)
my_menu.add_cascade (label="options",menu=options_menu)

options_menu.add_command(label="Play Again", command=reset)
options_menu.add_separator()

options_menu.add_command(label="how to play ?", command=open_secondary_window)
options_menu.add_separator()

options_menu.add_command(label="Exit", command=window.destroy)
options_menu.add_separator()



reset()
window.mainloop()
